# %% [markdown]
# Задача 1.
# Постройте график
# Назовите график
# Сделайте именование оси x и оси y
# Сделайте выводы
#
# 1.1. Скачать следующие данные: kc_house_data и laptop_price
# 1.2. Изучите стоимости недвижимости
# 1.3. Изучите распределение квадратуры жилой площади
# 1.4. Изучите распределение года постройки

# %% [markdown]
# 1.1 Скачать следующие данные: kc_house_data и laptop_price

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df1 = pd.read_csv('kc_house_data.csv', sep = ',', encoding = 'latin-1')
df1
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
import pandas as pd
df2 = pd.read_csv('laptop_price.csv', sep = ',', encoding = 'latin-1')
df2.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %% [markdown]
# 1.2. Изучите стоимости недвижимости

# %%
plt.figure(figsize=(8, 6))
plt.hist(df1['price'])
plt.title('Распределение стоимости недвижимости')
plt.xlabel('Стоимость')
plt.ylabel('Количество')
plt.grid()

# %%
min_price = df1['price'].min()
max_price = df1['price'].max()
print("Самая минимальная стоимость:", min_price, " долларов")
print("Самая максимальная стоимость:", max_price, " долларов")
# Out:
# Самая минимальная стоимость: 75000.0  долларов
# Самая максимальная стоимость: 7700000.0  долларов

# %% [markdown]
# Выводы: Больше всего по количеству (объектов) недвижимости до 1 млн и совсем мало со стоимостью более 2 млн. Количество домов обратно пропорционально их стоимости. Чем меньше стоимость, тем больше домов. Минимальная стоимость недвижимости 75000 $, максимальная - 7700000 $.

# %%
1.3. Изучите распределение квадратуры жилой площади

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df1['sqft_living'], bins=20)
plt.title('Распределение квадратуры жилой площади')
plt.xlabel('Кв. метры жилые')
plt.ylabel('Количество');
plt.grid()

# %%
min_sqft_living = df1['sqft_living'].min()
max_sqft_living = df1['sqft_living'].max()
print("Самый минимальный метраж:", min_sqft_living, " футов")
print("Самый максимальный метраж:", max_sqft_living, " футов")
# Out:
# Самый минимальный метраж: 290  футов
# Самый максимальный метраж: 13540  футов

# %% [markdown]
# Выводы: Больше всего домов с квадратурой в пределах от 1500 до 3000, меньше домов с квадратурой более 5000.
# Минимальная квадратура - 290 футов, максимальная 13540 футов.

# %% [markdown]
# 1.4. Изучите распределение года постройки

# %%
plt.figure(figsize=(6, 8))
sns.histplot(df1['yr_built'], bins=30)
plt.title('Распределение года постройки')
plt.xlabel('Год постройки')
plt.ylabel('Количество');

# %%
plt.boxplot(df1['yr_built'])
plt.title('Распределение года постройки')
plt.xlabel('Количество')
plt.ylabel('Год постройки')
plt.show()

# %%
filtered_data = df1[(df1['yr_built'] > 2000) & (df1['sqft_living'] > 0)]
cheapest_property = filtered_data[filtered_data['price'] == filtered_data['price'].min()]
print("Самая дешевая недвижимость, построенная после 2000 года с метражем больше 0:")
print(cheapest_property[['price', 'yr_built', 'sqft_living']])
# Out:
# Самая дешевая недвижимость, построенная после 2000 года с метражем больше 0:
#           price  yr_built  sqft_living
# 19650  155000.0      2013         1300

# %% [markdown]
# Общие выводы по задаче 1: Наблюдается преобладание (по количеству) недвижимости со средней площадью 2000 квадратных футов (610 квадратных метров), со cтоимостью около полумиллиона долларов, построенного во второй половине прошлого столетия. Наибольшее количество новых домов построено в начале десятых годов XXI века, предыдущим пик строительства зафиксирован в конце 70 годов XX века. Подавляющее количество объектов недвижимости находится в ценовом диапазоне до 4,000,000 долларов. Самая большая стоимость составляет 7700000 долларов, а самая большая площадь недвижимости - около 2,5 кв.км.. Самая минимальная цена на недвижимость - 75000 долларов, а самый минимальный метраж - около 88 кв.м. Самая подходящая по "цена/качество" недвижимость - это построенная после 2000 года (2013), с метражем 400 кв.м., по цене 155,000 долларов.

# %% [markdown]
# Задача 2.
# 2.1. Изучите распределение домов от наличия вида на набережную
# Постройте график
# Сделайте выводы
# 2.2. Изучите распределение этажей домов
# 2.3. Изучите распределение состояния домов

# %% [markdown]
# 2.1. Изучите распределение домов от наличия вида на набережную.
# Постройте график.
# Сделайте выводы

# %%
data = df1['waterfront'].value_counts()
plt.figure(figsize=(6, 4))
plt.pie(data, autopct='%1.1f%%')
plt.legend(['no', 'yes']);

# %% [markdown]
# Выводы: На круговой диаграмме видно, что подавляющее большинство домов не имеют вида на набережную, а домов с видом на набережную менее 1 % от общей массы.

# %%
2.2. Изучите распределение этажей домов

# %%
df1['floors'].value_counts().sort_index().plot(kind='bar')
plt.title('Распределение этажей домов')
plt.xlabel('Количество этажей')
plt.ylabel('Количество домов')
plt.show()

# %%
data = df1['floors'].value_counts()
plt.figure(figsize=(6, 4))
plt.pie(data, autopct='%1.1f%%', labels=data.index)
plt.title('Количество этажей');

# %% [markdown]
# Выводы: На графиках четко видно распределение домов по количеству этажей: наибольшее количество домов - одноэтажные, они составляют 49,4 % от общей массы домов.

# %%
2.3. Изучите распределение состояния домов

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df1, x='condition', hue='floors')
plt.title('Многорядная столбчатая диаграмма распределения состояния домов с учетом их этажности')
plt.xlabel('Состояние дома')
plt.ylabel('Количество домов')
plt.legend(title='Количество этажей')
plt.show()

# %% [markdown]
# Выводы: График многорядной столбчатой диаграммы демонстрирует распределение домов по разным уровням состояния. Здесь четко видно, что большинство домов находится в удовлетворительном состоянии (львиную долю здесь занимают двухэтажные и одноэтажные дома).

# %% [markdown]
# Задача 3.
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
# 1. График зависимости стоимости от квадратуры жилой площади (scatter plot)
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df1, x='sqft_living', y='price', alpha=0.7)
plt.title('Зависимость стоимости от квадратуры жилой площади')
plt.xlabel('Квадратура жилой площади')
plt.ylabel('Стоимость недвижимости (миллион долларов)')
plt.show()

# %% [markdown]
# Выводы: График показывает положительную корреляция между квадратурой жилой площади и стоимостью недвижимости - чем больше площадь дома, тем выше его стоимость.

# %%
# 2. График распределения стоимости недвижимости по количеству комнат (box plot)
plt.figure(figsize=(12, 8))
sns.boxplot(data=df1, x='bedrooms', y='price')
plt.title('Распределение стоимости недвижимости по количеству комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Стоимость недвижимости (миллион долларов)')
plt.show()

# %% [markdown]
# Выводы: На графике видно, что стоимость недвижимости варьируется в зависимости от количества комнат в доме. Дома с большим количеством комнат могут иметь более высокую стоимость, но есть также выбросы с низкой стоимостью для некоторых комбинаций количества комнат.

# %%
# 3. График распределения стоимости недвижимости по виду на набережную и количеству этажей (bar plot)
plt.figure(figsize=(10, 6))
sns.barplot(data=df1, x='waterfront', y='price', hue='floors')
plt.title('Распределение стоимости недвижимости по виду на набережную и этажам')
plt.xlabel('Вид на набережную')
plt.ylabel('Стоимость недвижимости (миллион долларов)')
plt.legend(title='Количество этажей')
plt.show()

# %% [markdown]
# Выводы: Многорядная столбчатая диаграмма позволяет сравнить среднюю стоимость недвижимости с видом на набережную и без него, а также учитывает влияние количества этажей. На графике видно, что дома с видом на набережную и несколькими этажами имеют более высокую среднюю стоимость.

# %%
# 4. График распределения стоимости недвижимости в зависимости от года постройки (box plot)
plt.figure(figsize=(20, 8))
sns.boxplot(data=df1, x='yr_built', y='price')
plt.xlabel('Год постройки')
plt.ylabel('Стоимость недвижимости (миллион долларов)')
plt.title('Распределение стоимости недвижимости по году постройки')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Выводы: График позволяет увидеть распределение стоимости недвижимости по годам постройки. Старые дома имеют разнообразные цены, но есть некоторые выбросы с высокой стоимостью. Дома, построенные недавно, имеют более высокую среднюю стоимость.

# %%
# 5. Построение тепловой карты
numeric_columns = df1.select_dtypes(include=['int64', 'float64'])
corr_matrix = numeric_columns.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Тепловая карта влияния характеристик на стоимость жилья')
plt.show()

# %% [markdown]
# Выводы: График позволяет увидеть прямопропорциональные и обратнопропорциональные зависимости характеристик недвижимости. Прямопропорциональные зависимости: например, чем больше жилая площадь (sqft_living), тем больше площадь дома без учета подвала (sqft_above); или чем больше стоимость (price), тем больше жилая площадь (sqft_living), количество ванных комнат (bathrooms) и спален (bedrooms). Обратнопропорциональные зависимости: например, чем выше год постройки (yr_built), тем хуже состояние (condition).
